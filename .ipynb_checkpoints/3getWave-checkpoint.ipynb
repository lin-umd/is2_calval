# %%
# read is2_calval
import geopandas as gpd 
import numpy as np
import os
import glob
import time
import subprocess
import multiprocessing
from tqdm import tqdm
# read H5 file 
import h5py
########
import utm
import pandas as pd
import math
import matplotlib.pyplot as plt
from scipy.stats import poisson
from shapely.geometry import Point

# %%
# read a wave h5 example 
file = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/result/usa/neon_wref2021/wave_NEON_D16_WREF_DP1_L078-1_2021072415_unclassified_point_cloud_0000005.h5'

# %%
with h5py.File(file, "r") as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    #print("Keys: %s" % f.keys())
    N_foorprints = f['RXWAVECOUNT'].shape[0]
    print(N_foorprints)
    #for i in range(0, N_foorprints):
    i=100
    RXWAVECOUNT = f['RXWAVECOUNT'][i] # all
    GRWAVECOUNT = f['GRWAVECOUNT'][i] # ground
    zStart = f["Z0"][i]
    zEnd = f["ZN"][i]
    zG = f["ZG"][i]
    wfCount = f["NBINS"][0]
    wfStart = 1
    # Calculate zStretch
    zStretch = zEnd + (np.arange(wfCount, 0, -1) * ((zStart - zEnd) / wfCount))
    plt.plot(RXWAVECOUNT, zStretch,color='red' )
    plt.plot(RXWAVECOUNT - GRWAVECOUNT, zStretch,color='black', linestyle='--' )
    plt.show()
# Out:
# 3422

# %%
# variables 
LAS_PATH = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/data/las'
RES_PATH = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/result'

# %%
#total_laz_files = glob.glob('/gpfs/data1/vclgp/data/gedi/imported/*/*/LAZ_ground/*.laz')
#print(len(total_laz_files)) # 358, 796 laz files.

# %%
# find weher is La_Selva_05102019_001_827300_1155500
#glob.glob('/gpfs/data1/vclgp/data/gedi/imported/*/*/LAZ_ground/La_Selva_05102019_001_827300_1155500.laz')

# %%
#laz_fs = glob.glob('/gpfs/data1/vclgp/data/gedi/imported/seasia/jpl_borneo_119/LAZ_ground/*.laz')
#las_out = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las/centralamerica/costarica_laselva2019'
#las_fs = glob.glob('/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las/centralamerica/costarica_laselva2019/*.las')
# for f in las_fs:
#     print(f)
#     #os.system(f'las2las -i {f} -odir {las_out} -olas')
#     os.system(f'lasinfo -i {f} ')

# %%
gdf_is2 = gpd.read_parquet('../result/is2_20m_calval_09252023.parquet') # 18550387 IS2 20 m segment points
# Specify the path to your GeoPackage file
als_sites = "../data/sites_20221006.gpkg"
# Read the GeoPackage file
gdf_als = gpd.read_file(als_sites)
# Now, gdf is a GeoDataFrame containing the data from the GeoPackage file

# %%
# test 4 mikhai 
#als_sites = "../data/atl08_v6_icepyx_welverdient_20m_filter_wgs84.gpkg"
#gdf_als = gpd.read_file(als_sites)
#gdf_als.plot()
#als_index = gdf_is2.sindex.query(gdf_als['geometry']) # super fast!!!!! # but only boundary box. 
#als_index 
#is2_in_als = gdf_is2.loc[als_index] 
#print(len(is2_in_als))
#is2_in_als = gdf_is2.clip(gdf_als['geometry'])  # get points inside polygon.
#len(is2_in_als)
# Out:
# 10170

# %%
gdf_is2['fid'] = gdf_is2.index

# %%
# is2_in_als # rgt_id_beg --> only locate 100 m segments. # in the future merge 20 m, change segment_id. 
# for is2_index, is2_row in is2_in_als[10:20].iterrows(): 
#     print(is2_index)
#len(is2_in_als)
#is2_in_als.plot()
#is2_in_als.total_bounds

# %%
def get_sim_rh(filename): # default read. 
                    # Canopy height, ch
                    # For a 100 m segment, the cumulative height distribution of canopy photons is 
                    # generated and the height at the 98th percentile.
                    with h5py.File(filename, "r") as f:
                        # Print all root level object names (aka keys) 
                        # these can be group or dataset names 
                        #print("Keys: %s" % f.keys())
                        N_foorprints = f['RXWAVECOUNT'].shape[0]
                        pho_w_ground = pd.DataFrame()
                        pho_no_ground = pd.DataFrame()
                        for i in range(0, N_foorprints):
                                    
                                    RXWAVECOUNT = f['RXWAVECOUNT'][i]
                                    GRWAVECOUNT = f['GRWAVECOUNT'][i]
                                    zStart = f["Z0"][i]
                                    zEnd = f["ZN"][i]
                                    zG = f["ZG"][i]
                                    wfCount = f["NBINS"][0]
                                    if (wfCount < 1): continue
                                    wfStart = 1
                                    # Calculate zStretch
                                    zStretch = zEnd + (np.arange(wfCount, 0, -1) * ((zStart - zEnd) / wfCount))
                                    #plt.plot(RXWAVECOUNT, zStretch,color='red' )
                                    #plt.plot(RXWAVECOUNT - GRWAVECOUNT, zStretch,color='black', linestyle='--' )
                                    #plt.show()
                                    # sampling 
                                    n = np.random.poisson(3,1)[0] # posson sample, how many photons?
                                    
                                    # canopy + ground photons
                                    rows = np.arange(RXWAVECOUNT.shape[0])
                                    total = sum(RXWAVECOUNT)
                                    
                                    # Normalize the data by dividing each value by the total
                                    p_data = [value / total for value in RXWAVECOUNT]
                                    photon_rows = np.random.choice(rows, size=n, p=p_data)
                                    df1 = zStretch[photon_rows] - zG
                                    df1 = pd.DataFrame(df1)
                                    if (len(pho_w_ground) == 0):
                                        pho_w_ground = df1
                                    else:
                                        #print(df1)
                                        pho_w_ground = pd.concat([pho_w_ground, df1], ignore_index=True)
                                    # # canopy photons only
                                    canopy_wave = RXWAVECOUNT - GRWAVECOUNT
                                    
                                        
                                    total = sum(canopy_wave)
                                    if (total == 0 ): continue
                                    # fill NAs.
                                    #canopy_wave = np.nan_to_num(canopy_wave, nan=0.0)
                                    # Normalize the data by dividing each value by the total
                                    p_data = [value / total for value in canopy_wave]
                                    photon_rows = np.random.choice(rows, size=n, p=p_data)
                                    df1 = zStretch[photon_rows] - zG
                                    df1 = pd.DataFrame(df1)
                                    if (len(pho_no_ground) == 0):
                                        pho_no_ground = df1
                                    else:
                                        pho_no_ground = pd.concat([pho_no_ground, df1], ignore_index=True)
                    f.close()
                    percentiles = np.arange(1, 101, 1)
                    height_percentiles = np.percentile(pho_no_ground, percentiles)
                    ch_98 = height_percentiles[97] ### h_98
                    
                    # rh 
                    percentiles = np.arange(0, 101, 1)
                    #0 --> min height
                    # 100 --> max height
                    height_percentiles = np.percentile(pho_w_ground, percentiles)
                    # data frame from 0 to 100
                    column_names = ["rh" + str(i) for i in range(101)]  # Creates a list from rh0 to rh100
                    sim = pd.DataFrame(columns=column_names)
                    # Add your array as a row to the DataFrame
                    sim.loc[0] = height_percentiles
                    sim['h_canopy_98'] = ch_98
                    return sim

# %%
# lat lon to UTM 
# e1, n1 , zone1, letter1 = utm.from_latlon(lat_c, lon_c)

# %%
# return all is2 points in laz boundary 
def sim_is2_laz(is2_in_als_utm , laz_path):
#laz_path = '/gpfs/data1/vclgp/data/gedi/imported/usa/usda_or/LAZ_ground/or_10_101.laz'
                    als_name = laz_path.split('/')[-3]
                    region = laz_path.split('/')[-4]
                    bounds_file = '/gpfs/data1/vclgp/data/gedi/imported/lists/ground_bounds/boundGround.' + als_name+ '.txt'
                    df = pd.read_csv(bounds_file, header = None, sep = " ")
                    #print('# las file : \n', laz_path)
                    df.columns = ['file', 'xmin', 'ymin', 'zmin', 'xmax', 'ymax', 'zmax']
                    basename = os.path.basename(laz_path)
                    d_file = df[df['file'].str.contains(basename[:-4])]
                    #print( '# laz file bounds: ',d_file.iloc[:, 1:6])
                    xmin = d_file['xmin'] 
                    xmax = d_file['xmax'] 
                    ymin = d_file['ymin'] 
                    ymax = d_file['ymax'] 
                    # get laz and nearby laz 
                    from shapely.geometry import Polygon
                    # Create a Polygon geometry from the coordinates
                    polygon = Polygon([(xmin, ymin), (xmax, ymin), (xmax, ymax), (xmin, ymax)])
                    # return is2_in_als -----
                    is2_laz = is2_in_als_utm.clip(polygon)
                    #print('# is2_laz: \n', is2_laz)
                    if (len(is2_laz) == 0):
                        #print('# no is2 20m segment is in this las file!')
                        return None
                    # get footprints 
                    ###########################################################
    ###########################################################################
                    # should i get 1 las file  ---> 1 wave.h5?
                    # start from one segment -- one row 
                    
                    print('# number of is2 20m segments in las file: ', len(is2_laz))
                    segment_footprints_utm = get_footprint(is2_laz) # get all 
                        # create result folder /region/name/
                    res_out = RES_PATH + '/' + region + '/' + als_name 
                    os.makedirs( res_out , exist_ok = True)
    
                    out_coor = res_out+ '/coordinates_'+ basename[:-4] + '.txt'####
                    #out_las_txt = res_out+ '/lasfiles_'+ basename[:-4] + '.txt'
                    out_wave = res_out+ '/wave_'+ basename[:-4] + '.h5'
                    segment_footprints_utm[['e', 'n']].to_csv(out_coor, sep=' ', header = False,  index = False)
                    ##### laz boundary problem is not solved ....
                    ##### #######################################################################################
                    # geometries = [Polygon([(row['xmin'], row['ymin']), (row['xmin'], row['ymax']), 
                    #                                    (row['xmax'], row['ymax']), (row['xmax'], row['ymin'])])
                    #                           for _, row in df.iterrows()]
                    # # Create a GeoDataFrame with the rectangles
                    # gdf = gpd.GeoDataFrame(df, geometry=geometries)
                    # laz_want = gdf.sindex.query(polygon)
                    # #gdf.loc[laz_want].plot(facecolor='none', edgecolor='red')
                    # laz_nearby = gdf.loc[laz_want]
                    # #print( '# convert laz to las files if not exist...') 
                    # for laz_index, laz_row in laz_nearby.iterrows(): 
                    #      laz_path = laz_row['file']
                    #      # /gpfs/data1/vclgp/data/gedi/imported/usa/usda_or/ALS_ground/or_10_101.las
                    #      laz_path = laz_path.replace('ALS_ground', 'LAZ_ground').replace('.las', '.laz')
                    #      las_out = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las/' + region + '/' + als_name
                    #      os.makedirs( las_out , exist_ok = True)
                    #      bs = os.path.basename(laz_path)
                    #      bs_las = bs[:-1] + 's'
                    #      # check if las file exist:
                    #      bs_las_path = las_out+'/'+bs_las
                    #      if not os.path.isfile(bs_las_path):
                    #                 #print('not exist')
                    #                 print('# converting laz file: ', laz_path )
                    #                 os.system(f'las2las -i {laz_path} -odir {las_out} -olas')
                    # split_columns = laz_nearby['file'].str.split('/')
                    
                    # new_path = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las/' + split_columns.str[-4] + '/' + split_columns.str[-3] + '/' + split_columns.str[-1]
                    # new_path.to_csv(out_las, sep=' ', header = False,  index = False) 
                    #####################################################################################
                    # directly run 
                    # #######################################
                    #####
                    
                    # /gpfs/data1/vclgp/data/gedi/imported/usa/usda_or/ALS_ground/or_10_101.las
                    laz_path = laz_path.replace('ALS_ground', 'LAZ_ground').replace('.las', '.laz')
                    las_out = LAS_PATH + '/' + region + '/' + als_name
                    os.makedirs( las_out , exist_ok = True)

                    bs = os.path.basename(laz_path)
                    bs_las = bs[:-1] + 's'
                    # check if las file exist:
                    bs_las_path = las_out+'/'+bs_las
                    if not os.path.isfile(bs_las_path):
                            #print('not exist')
                            print('# converting laz file: ', laz_path )
                            os.system(f'las2las -i {laz_path} -odir {las_out} -olas')
                    os.system(f'las2las -i {laz_path} -odir {las_out} -olas')
                    #new_path = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las/' + split_columns.str[-4] + '/' + split_columns.str[-3] + '/' + split_columns.str[-1]
                    # it is a string, not a dataframe

                    # with open(out_las_txt, 'w') as file:
                    #         file.write(bs_las_path)
                    #new_path.to_csv(out_las, sep=' ', header = False,  index = False) 
                    #######################################################################################
                    #print('bs_las_path', bs_las_path)
                    os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -input {bs_las_path} -listCoord {out_coor}  -output {out_wave} -hdf  -ground > running.log')
                    #os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -inList {out_las_txt} -listCoord {out_coor}  -output {out_wave} -hdf  -ground > running.log')
                    #print('# get ch98 , rh and fid ???')
                    # df_tmp = pd.DataFrame()
                    # try:
                    #      df_tmp = get_sim_rh(out_wave)
                    #      df_tmp['fid'] = fid
                    # #      print('# sim result length: ', len(df_tmp))
                    #      results.append(df_tmp)
                    # except:
                    #      pass
                    # if (len(results) > 0):
                    #             # write to parquet 
                    #             las_sim_result = pd.concat(results, ignore_index=True)
                    #             print('# write simulation result for this las file...')
                    #             las_sim_result.to_parquet('../wave/sim_las_'+ basename[:-3] + 'parquet')
                    #             #return pd.concat(results, ignore_index=True)
#laz_path = '/gpfs/data1/vclgp/data/gedi/imported/usa/neon_sawb/LAZ_ground/L26_2014_BURL_1_v01_2014053013_P01_r.laz'                        
#sim_is2_laz(is2_in_als_utm , laz_path)

# %%
# test  seasia_jpl_borneo_119
#laz_path = '/gpfs/data1/vclgp/data/gedi/imported/seasia/jpl_borneo_119/LAZ_ground/features-2_l2d_s1c2_0000005.laz'       
#sim_is2_laz(is2_in_als_utm , laz_path)
#segment2footprints(is2_in_als) # 480,744
#out_coor = '../wave/coordinates_utm_sites.txt'
#data_path = '/gpfs/data1/vclgp/data/gedi/imported/' + row['region'] + '/' + row['name'] + '/LAZ_ground'
#data_path
# /gpfs/data1/vclgp/data/gedi/imported/lists/ground_bounds
# gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -inList alslist.txt -listCoord ../wave/coordinates_utm_sites.txt  -output wave.h5 -hdf  -ground
#os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -inList alslist.txt -listCoord {out_coor}  -output wave.h5 -hdf  -ground')

# %%
def las_list(data_path = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las'):
#data_path = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las'
                files_las = [os.path.join(data_path, file)
                         for file in os.listdir(data_path) 
                         if os.path.isfile(os.path.join(data_path, file))]
                # Open the output text file in write mode
                with open("../wave/alslist.txt", "w") as file: # als list should be different
                    # Write each file name to a new line in the text file
                    for file_name in files_las:
                        file.write(file_name + "\n")
                # Close the file
                file.close()
def is2_geo_utm(is2_in_als):
        for is2_index, is2_row in is2_in_als.iterrows():   
                lat_c = is2_row['land_segments/latitude_20m'] 
                lon_c = is2_row['land_segments/longitude_20m']
                e, n , zone, letter = utm.from_latlon(lat_c, lon_c)
                is2_in_als.loc[is2_index, 'e'] = e
                is2_in_als.loc[is2_index, 'n'] = n
                is2_in_als.loc[is2_index, 'zone'] = zone
        # Create a GeoDataFrame with a Point geometry
        geometry = [Point(x, y) for x, y in zip(is2_in_als['e'], is2_in_als['n'])]
        is2_in_als_utm = gpd.GeoDataFrame(data = is2_in_als, geometry=geometry)
        return is2_in_als_utm

def get_footprint(is2_laz):
    res_footprints = []
    for is2_index, is2_row in is2_laz.iterrows():
                    lat_c = is2_row['land_segments/latitude_20m'] 
                    lon_c = is2_row['land_segments/longitude_20m'] 
                    slope = is2_row['slope']
                    e1, n1 , zone1, letter1 = utm.from_latlon(lat_c, lon_c)
                    theta = math.atan(slope)
                    data = np.arange(-14, 15) # -14 --14
                    e_array = e1 + data * 0.7*math.cos(theta)
                    n_array = n1 + data * 0.7*math.sin(theta)
                    coordinates_utm = pd.DataFrame({'e': e_array, 'n': n_array})# .round(2).applymap(lambda x: f'{x:.2f}')  # keep 2 decimals.       
                    res_footprints.append(coordinates_utm)
    res_footprints = pd.concat(res_footprints, ignore_index=True)
    return res_footprints
     #coordinates_utm_sites_df #.to_csv('../wave/coordinates_utm_sites.txt', sep=' ', header = False,  index = False) # coordinates should be differnt. 



# Loop through every row in the GeoDataFrame

# %%
def rm_files(data_path = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las'):
                    # List all files in the folder
                    file_list = os.listdir(data_path)
                    # keep large files to save time for next time
                    if (len(file_list) > 1000): 
                        return None
                    # Loop through the files and delete them
                    for filename in file_list:
                        file_path = os.path.join(data_path, filename)
                        if os.path.isfile(file_path):
                            os.remove(file_path)
                            #print(f"Deleted: {file_path}")
#rm_files()

# %%
###### loop through every project  ---- return a is2_cal_va
# get possible las files for each segment. 
# function convert laz to las .... 
# Loop through every row in the GeoDataFrame
# 400 sites, parellel??? no need, may need!!! 
for index, row in gdf_als[5:6].iterrows(): 
        # Open a text file named "output.txt" in write mode
        with open('processing.txt', 'w') as file:
            # Write text to the file
            file.write('# index: {}\n'.format(index))
            file.write('# now processing als project: {}\n'.format(row['region'] + '_' + row['name']))

        # The file will be automatically closed when you exit the 'with' block
        # the bounding box of each input geometry intersects the bounding box
        als_index = gdf_is2.sindex.query(row['geometry']) # super fast!!!!! # but only boundary box. 
        is2_in_als = gdf_is2.loc[als_index] 
        #print(len(is2_in_als))
        is2_in_als = is2_in_als.clip(row['geometry'])  # get points inside polygon.
        #out_name = '../result/is2_calval_region/is2_' + row['region'] + '_' + row['name'] + '.parquet'
        print('# now processing als project: ', row['region'] + '_' + row['name'])
        #is2_in_als.to_parquet(out_name)   # save is2 footprints in this als site
        print("# is2 points in this als project: ", len(is2_in_als))
        print('# convert segments in utm...')
        ##############################################################
        for is2_index, is2_row in is2_in_als.iterrows():   
                lat_c = is2_row['land_segments/latitude_20m'] 
                lon_c = is2_row['land_segments/longitude_20m']
                e, n , zone, letter = utm.from_latlon(lat_c, lon_c)
                is2_in_als.loc[is2_index, 'e'] = e
                is2_in_als.loc[is2_index, 'n'] = n
                is2_in_als.loc[is2_index, 'zone'] = zone
        # Create a GeoDataFrame with a Point geometry
        geometry = [Point(x, y) for x, y in zip(is2_in_als['e'], is2_in_als['n'])]
        is2_in_als_utm = gpd.GeoDataFrame(data = is2_in_als, geometry=geometry)
        ########################################################### 
        data_path = '/gpfs/data1/vclgp/data/gedi/imported/' + row['region'] + '/' + row['name'] + '/LAZ_ground'
        # convert all laz file to las files
        files_path = data_path + '/*.laz' 
        laz_files = glob.glob(files_path)
        print('# number of laz files: ', len(laz_files))
        nCPU = len(laz_files)
        if nCPU > 10 : 
           nCPU = 10  # number of cores to use  
        print('# parallel processing...')
        pool = multiprocessing.Pool(nCPU) # Set up multi-processing
        progress_bar = tqdm(total=len(laz_files))
        def update_progress_bar(_):
              progress_bar.update()  
        for laz_f in laz_files:
            pool.apply_async(sim_is2_laz, (is2_in_als_utm, laz_f), callback=update_progress_bar)
        pool.close()
        pool.join()
        # Close the progress bar
        progress_bar.close()
        # out las path 
        # las_out = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las/' + row['region'] + '/' + row['name']
        # print('# convert laz files to las...')
        # os.makedirs( las_out , exist_ok = True)
        # for f_laz in laz_files: # parallel processing to convert files if over > 500.################################################################
        #     bs = os.path.basename(f_laz)
        #     bs_las = bs[:-1] + 's'
        #     # check if las file exist:
        #     bs_las_path = las_out+'/'+bs_las
        #     if not os.path.isfile(bs_las_path):
        #         #print('not exist')
        #         os.system(f'las2las -i {f_laz} -odir {las_out} -olas') # convert data to las folder  # folder should be different when parallel. 
        # # write to als list
        # las_list(las_out)
        # step: loop through every 20 m segment #  480844 points, parallel ???
        # directly read ---las files and footprints. 
        # out_coor = '../wave/coordinates_utm_sites.txt'
        # als_list = '../wave/alslist.txt'
        # out_wave = '../wave/wave_'+ row['region'] + '_' + row['name'] + '.h5'
        # os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -inList {als_list} -listCoord {out_coor}  -output {out_wave} -hdf  -ground')
        # # nCPU = len(is2_in_als)
        # if nCPU > 20 : 
        #    nCPU = 20  # number of cores to use  
        # print('# parallel processing...')
        # pool = multiprocessing.Pool(nCPU) # Set up multi-processing
        # progress_bar = tqdm(total=len(is2_in_als))
        # def update_progress_bar(_):
        #       progress_bar.update()  
        # results = []
        # for is2_index, is2_row in is2_in_als.iterrows():   # no need for every footprint. 
        #         #get_sim(is2_index,is2_row)
        #         tmp = pool.apply_async(get_sim, (is2_index,is2_row), callback=update_progress_bar)
        #         results.append(tmp)
        # myresult = pd.concat([result.get() for result in results], ignore_index=True)
        #                 #print(is2_row)
        #                 # 29.053188, -110.62982
        #                 # lat_c = is2_row['land_segments/latitude_20m'] 
        #                 # lon_c = is2_row['land_segments/longitude_20m'] 
        #                 # slope = is2_row['slope']
        #                 # fid = is2_row['fid']
        #                 # e1, n1 , zone1, letter1 = utm.from_latlon(lat_c, lon_c)
        #                 # theta = math.atan(slope)
        #                 # data = np.arange(-14, 15) # -14 --14
        #                 # e_array = e1 + data * 0.7*math.cos(theta)
        #                 # n_array = n1 + data * 0.7*math.sin(theta)
        #                 # lat_, lon_ = utm.to_latlon(e_array, n_array, zone1, letter1)
        #                 # coordinates = pd.DataFrame({'lat': lat_, 'lon': lon_})
        #                 # coordinates_utm = pd.DataFrame({'e': e_array, 'n': n_array})
        #                 # coordinates_utm.to_csv('coordinates.txt', sep=' ', header = False,  index = False) # coordinates should be differnt. 
        #                 # # run simulator
        #                 # os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -inList alslist.txt -listCoord coordinates.txt  -output wave.h5 -hdf  -ground > running.log')
        #                 # # get ch_98 and rh_metrics
        #                 # df_tmp = get_sim_rh()
        #                 # df_tmp['fid'] = fid
        #                 #df.append(df_tmp)
        # # save the result 
        # # Concatenate the DataFrames into a single DataFrame
        # #combined_df = pd.concat(df, ignore_index=True)
        # out_name = '../result/is2_calval_region/is2_sim_' + row['region'] + '_' + row['name'] + '.parquet'
        # myresult.to_parquet(out_name)  
        #rm_files(las_out) # remove las files when done
        print('# als project:', row['region'] + '_' + row['name'], ' is done!')
        # gdf.to_parquet('data.parquet')  
        #out_name = '../result/is2_calval_region/is2_' + row['region'] + '_' + row['name'] + '.parquet'
        #is2_in_als.to_parquet(out_name)
        # data laz
        # Do something with the data from the row
        #print(data_path)
        # Use os.listdir to get a list of all items in the folder
        #items = os.listdir(data_path)
        # Use a list comprehension to filter out files (excluding subfolders)
        #files = [item for item in items if os.path.isfile(os.path.join(data_path, item))]
        # Get the count of files
        #print(len(files), data_path)
# Out:
# # now processing als project:  seasia_jpl_borneo_119
# # is2 points in this als project:  395
# # convert segments in utm...
# # number of laz files:  36
# # parallel processing...
#   3%|▋                        | 1/36 [00:00<00:05,  6.57it/s]
# # number of is2 20m segments in las file: # number of is2 20m segments in las file: # number of is2 20m segments in las file: # number of is2 20m segments in las file: # number of is2 20m segments in las file:  305
# 66651236
#
#
#
# # number of is2 20m segments in las file:  3
# # number of is2 20m segments in las file:  9
# # number of is2 20m segments in las file: 3
# # number of is2 20m segments in las file:  76
# # number of is2 20m segments in las file:  70
# Error reading point data, size 199999968
#  22%|█████▌                   | 8/36 [00:03<00:12,  2.31it/s]
# # number of is2 20m segments in las file:  3
#  33%|████████                | 12/36 [00:05<00:10,  2.29it/s]
# # number of is2 20m segments in las file:  3
#  36%|████████▋               | 13/36 [00:05<00:09,  2.49it/s]
# # number of is2 20m segments in las file:  65
#  42%|██████████              | 15/36 [00:08<00:14,  1.44it/s]
# # number of is2 20m segments in las file:  181
#  67%|████████████████        | 24/36 [00:09<00:03,  3.75it/s]
# # number of is2 20m segments in las file:  32
# # number of is2 20m segments in las file:  48
# Error reading point data, size 199999968
#  75%|██████████████████      | 27/36 [00:18<00:09,  1.04s/it]Error reading point data, size 199999968
# 100%|████████████████████████| 36/36 [03:52<00:00,  6.45s/it]
# # als project: seasia_jpl_borneo_119  is done!

# %%
fig, ax = plt.subplots()
# Plot the first GeoDataFrame
# Plot the second GeoDataFrame on the same axis
gdf_als.iloc[2:3].plot(ax=ax, color='red', label='ALS')
is2_in_als.plot(ax=ax, color='blue', label='IS2')
# Display the plot
plt.show()

# %%
# Define the pattern you want to match
pattern = '/gpfs/data1/vclgp/data/gedi/imported/*/*/LAZ_ground'
# Use glob to find matching folders
matching_folders = glob.glob(pattern)
# Count the matching folders
num_matching_folders = len(matching_folders)
print(f"Number of matching folders: {num_matching_folders}")
# Total number of LAZ files: 358796
# Number of matching folders: 469 --- as of date
# Out:
# Number of matching folders: 469

# %%
# # Check if the GDF contains points
# for index, point in gdf_is2.iterrows():
# Access the geometry of the point
#print(point)
point_geometry = gdf_is2.iloc[1]['geometry']
intersection_result = gdf_als[gdf_als.intersects(point_geometry)]
print(intersection_result)
# # Assign a value to a specific column at the target index
# if (len(intersection_result) == 0): continue
# gdf_is2.at[index, 'region'] = intersection_result['region'].iloc[0]
# gdf_is2.at[index, 'name'] = intersection_result['name'].iloc[0]
# Out:
#    region               name        area_ha  \
# 12    usa  canada_2010_32613  311580.069386
#
#                                              geometry
# 12  MULTIPOLYGON (((-112.90109 61.56746, -112.7581...

# %%
# give me lon, lat, slope, return 28 is2 footprint center

# %%
# give me lon, lat, slope, return als site name 
# return the laz file for the footprint

#data_path = '/gpfs/data1/vclgp/data/gedi/imported/'+ intersection_result['region'].iloc[0] +  '/'+ intersection_result['name'].iloc[0] + '/LAZ_ground'
data_path = '/gpfs/data1/vclgp/data/gedi/imported/usa/neon_harv2019/LAZ_ground'
files = [os.path.join(data_path, file)
         for file in os.listdir(data_path) 
         if os.path.isfile(os.path.join(data_path, file))]
print(len(files))
files[1]
# Out:
# 101
# '/gpfs/data1/vclgp/data/gedi/imported/usa/canada_2010_32613/LAZ_ground/S1C1_T26_YK_FF002_23_0000000.laz'

# %%
data_path
# Out:
# '/gpfs/data1/vclgp/data/gedi/imported/usa/cflra_waldepeteking/LAZ_ground'

# %%
# gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse ...
lon = gdf_is2.iloc[1]['land_segments/longitude_20m']
lat = gdf_is2.iloc[1]['land_segments/latitude_20m']
data_path = '/gpfs/data1/vclgp/data/gedi/imported/usa/neon_harv2019/LAZ_ground'
lat = 42.441517 ; lon = -72.24398; slope = -7.7
import utm
e1, n1 , zone1, letter1 = utm.from_latlon(lat, lon)
bbox = pd.read_csv('/gpfs/data1/vclgp/data/gedi/imported/lists/ground_bounds/boundGround.neon_harv2019.txt', sep=" ", header=None)
bbox.columns = ['f', 'xmin', 'ymin', 'zmin','xmax', 'ymax', 'zmax']
f =  bbox[ (bbox['xmin']  < e1) & (bbox['xmax']  > e1) & 
(bbox['ymin']  < n1) & (bbox['ymax']  > n1 )   ] ['f'].iloc[0]
f = os.path.basename(f)
f = [file for file in files_las if f in file][0]
f
# Out:
# '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/las/NEON_D01_HARV_DP1_L021-1_2019082013_unclassified_point_cloud_0000005.las'

# %%
# read als list 
#os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -inList alslist.txt -listCoord coordinates.txt  -output wave.h5 -hdf  -ground')

# %%
# test read laz files 
f = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/data/las/seasia/jpl_borneo_119/features-2_l2d_s1c2_0000005.las'
# with open('test.txt', 'w') as file:
#     file.write(f)

e1 = 600753.192661347 
n1 = 5114309.305307095
os.system(f'lasinfo {f}')
#os.system(f'gediRat -input {f} -coord {e1} {n1} -output waveform.txt -ground')
#os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -input {f} -coord {e1} {n1} -output wave_single.h5 -hdf -ground ')
#os.system(f'gediMetric -input wave_single.h5 -readHDFgedi -ground  -outRoot wave -rhRes 2')
# Out:
# lasinfo (171231) report for /gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/data/las/seasia/jpl_borneo_119/features-2_l2d_s1c2_0000005.las
# reporting all LAS header entries:
#   file signature:             'LASF'
#   file source ID:             0
#   global_encoding:            0
#   project ID GUID data 1-4:   0000024F-0000-FFFF-FFFF-000072770000
#   version major.minor:        1.2
#   system identifier:          'LAStools (c) by rapidlasso GmbH'
#   generating software:        'las2las (version 171231)'
#   file creation day/year:     333/2015
#   header size:                227
#   offset to point data:       321
#   number var. length records: 1
#   point data format:          3
#   point data record length:   34
#   number of point records:    17366077
#   number of points by return: 6814407 5367798 3453876 1729996 0
#   scale factor x y z:         0.01 0.01 0.01
#   offset x y z:               0 0 0
#   min x y z:                  215908.30 9760000.00 3.50
#   max x y z:                  217999.99 9761999.99 715.03
# variable length header record 1 of 1:
#   reserved             0
#   user ID              'LASF_Projection'
#   record ID            34735
#   length after header  40
#   description          'by LAStools of rapidlasso GmbH'
#     GeoKeyDirectoryTag version 1.1.0 number of keys 4
#       key 1024 tiff_tag_location 0 count 1 value_offset 1 - GTModelTypeGeoKey: ModelTypeProjected
#       key 3072 tiff_tag_location 0 count 1 value_offset 32750 - ProjectedCSTypeGeoKey: WGS 84 / UTM 50S
#       key 3076 tiff_tag_location 0 count 1 value_offset 9001 - ProjLinearUnitsGeoKey: Linear_Meter
#       key 4099 tiff_tag_location 0 count 1 value_offset 9001 - VerticalUnitsGeoKey: Linear_Meter
# reporting minimum and maximum for all LAS point record entries ...
# ERROR: 'end-of-file' after 11152916 of 17366077 points
#   X            21600000   21799999
#   Y           976000000  976155308
#   Z                 350      71503
#   intensity           1        102
#   return_number       1          4
#   number_of_returns   1          4
#   edge_of_flight_line 0          1
#   scan_direction_flag 0          1
#   classification      1          2
#   scan_angle_rank   -21         21
#   user_data           0          0
#   point_source_ID     7         14
#   gps_time 98418808.561227 98420718.093360
# WARNING: range violates GPS week time specified by global encoding bit 0
#   Color R 0 0
#         G 0 0
#         B 0 0
# number of first returns:        4431342
# number of intermediate returns: 3279543
# number of last returns:         4421078
# number of single returns:       979047
# WARNING: real number of point records (11152916) is different from header entry (17366077).
# WARNING: for return 1 real number of points by return (4431342) is different from header entry (6814407).
# WARNING: for return 2 real number of points by return (3447542) is different from header entry (5367798).
# WARNING: for return 3 real number of points by return (2192522) is different from header entry (3453876).
# WARNING: for return 4 real number of points by return (1081510) is different from header entry (1729996).
# overview over number of returns of given pulse: 979047 2505492 3331776 4336601 0 0 0
# histogram of classification of points:
#         10078769  unclassified (1)
#          1074147  ground (2)
# 0

# %%
# right footprint width (11 m diameter, 2,75 m sigma)
# coordinates.txt

# 4 * 2.75 = 11 m IS2 footprint
# coordinates = pd.read_csv('coordinates.txt', header = None, sep = " ")
# coordinates.columns = ['e', 'n']
# result = pd.DataFrame()
# for index, row in coordinates.iterrows():
#     e = row['e']
#     n = row['n']
#     os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -input {f} -coord {e} {n} -output waveform.txt -ground ')
#     # read waveform.txt
#     wave_dn = pd.read_csv('waveform.txt', sep=' ', header=None, skiprows=6)
#     ground = pd.read_csv('waveform.txt', sep=' ', header=None, skiprows=5, nrows = 1)
#     ground  = ground.iloc[0,2] # get ground values
    
#     # number of samples in this footprint
#     n = np.random.poisson(3,1)[0] # posson sample, how many photons?
#     # Your data
#     data = wave_dn[1]  
#     rows = np.arange(data.shape[0])
#     # Calculate the sum of all values in the dataset
#     total = sum(data)
#     # Normalize the data by dividing each value by the total
#     p_data = [value / total for value in data]
#     photon_rows = np.random.choice(rows, size=n, p=p_data)
#     ele = wave_dn[0]
#     df1 = ele[photon_rows].reset_index(drop=True)- ground
#     if (len(result) == 0):
#         result = df1
#     else:
#         result = pd.concat([df1, result], ignore_index=True)
#os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -input {f} -listCoord coordinates.txt  -output wave.h5 -hdf  -ground ')

# %%
get_sim_rh('wave_14822700.h5')
# Out:
#         rh0       rh1       rh2       rh3       rh4       rh5       rh6  \
# 0 -1.996832 -1.708391 -1.512531 -1.316516 -1.094312 -0.919494 -0.865467
#
#         rh7       rh8       rh9  ...       rh92       rh93      rh94  \
# 0 -0.813236 -0.778724 -0.763614  ...  21.663001  21.951215  22.07241
#
#         rh95       rh96       rh97       rh98       rh99      rh100  \
# 0  22.170569  22.405563  22.761852  23.096208  23.514546  24.293149
#
#    h_canopy_98
# 0    26.470054
#
# [1 rows x 102 columns]

# %%
# Create a scatter plot
plt.scatter(pho_no_ground.index, pho_no_ground, color='red', marker='o')
plt.scatter(pho_w_ground.index, pho_w_ground, color='blue', marker='.')
plt.show()

# %%
# get c_h, For a 
#1the cumulative height distribution of canopy photons is generated and the height at the 98th percentile.

percentiles = np.arange(1, 101, 1)
height_percentiles = np.percentile(pho_no_ground, percentiles)
plt.plot(percentiles, height_percentiles, marker='o', linestyle='-')
plt.xlabel('Percentile (%)')
plt.ylabel('Height (cm)')
plt.title('Percentile-Height Plot')
plt.grid(True)
plt.axhline(y=height_percentiles[97] , color='black', linestyle='--', label='h_98% [m]')
plt.legend()
# Show the plot
plt.show()
height_percentiles[97] ### h_98
# Out:
# 27.863449330558282

# %%
# Relative Height (RH) metrics from  pho_w_ground
percentiles = np.arange(0, 101, 1)
#0 --> min height
# 100 --> max height
height_percentiles = np.percentile(pho_w_ground, percentiles)
plt.plot(percentiles, height_percentiles, marker='o', linestyle='-')
plt.xlabel('Percentile (%)')
plt.ylabel('Height (cm)')
plt.title('Percentile-Height Plot')
plt.grid(True)
plt.axhline(y=height_percentiles[97] , color='black', linestyle='--', label='h_98% [m]')
plt.legend()
# Show the plot
plt.show()

# data frame from 0 to 100
column_names = ["rh" + str(i) for i in range(101)]  # Creates a list from rh0 to rh100

rh = pd.DataFrame(columns=column_names)

# Add your array as a row to the DataFrame
rh.loc[0] = height_percentiles
rh
# Out:
#         rh0       rh1       rh2       rh3       rh4       rh5       rh6  \
# 0 -0.969771 -0.921829 -0.809947 -0.713351 -0.664922 -0.487743 -0.409891
#
#         rh7       rh8       rh9  ...       rh91       rh92       rh93  \
# 0 -0.323487 -0.194735 -0.025567  ...  23.793195  23.878861  24.002468
#
#         rh94       rh95     rh96       rh97       rh98       rh99      rh100
# 0  24.207208  24.454726  24.5771  25.412019  26.420553  27.403565  28.182676
#
# [1 rows x 101 columns]

# %%
wave_dn = pd.read_csv('waveform.txt', sep=' ', header=None, skiprows=6)
wave = pd.read_csv('wave.metric.txt', sep=' ', header=None, skiprows=1)
name = pd.read_csv('wave.metric.txt',  header=None, nrows=1)
name = name.iloc[:, :-1]

# %%
# Split every cell by space and get the second word
# Convert the DataFrame to a list of strings
  # Get the data for the specified row
colnames = []
for column_name, value in name.iloc[0].items():
    first_letter_index = next((i for i, c in enumerate(value) if c.isalpha()), None)
    #print(value[first_letter_index:].replace(" ", "_"))
    colnames.append(value[first_letter_index:].replace(" ", "_"))
wave.columns = colnames
#wave.iloc[0, 166:217]# Get columns from index 50 to 100 (inclusive)

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# # Sample y values (you can replace this with your actual data)
# # Create a plot
# # wave.iloc[:, 76:97]
# x=np.arange(0,101,2)
# for index, row in wave.iterrows():
#     y = wave.iloc[index, 166:217]
#     plt.plot(x, y )#, label='Waveform' + str(index))
# # Draw the vertical line
# plt.axvline(x=98, color='black', linestyle='--', label='rh98')
# # Add labels and a title
# plt.xlabel('rh')
# plt.ylabel('height')
# # Add a legend
# plt.legend()
# # Show the plot
# plt.show()

# %%
plt.plot(wave_dn[1] * 100/ max(wave_dn[1]), wave_dn[0] )
x=np.arange(0,101,2)
plt.plot(x, wave.iloc[0, 166:217] +  wave['true_ground'][0])
# Draw the horizontal line
plt.axhline(y=wave['rhReal_100'][0] + wave['true_ground'][0], color='black', linestyle='--', label='Rh100')
plt.axhline(y=wave['true_top'][0], color='red', linestyle='--', label='Top')
plt.axhline(y=wave['true_ground'][0], color='blue', linestyle='--', label='Ground')
plt.axhline(y=wave['rhReal_0'][0] + wave['true_ground'][0], color='cyan', linestyle='--', label='Rh0')
# Add labels and a title
plt.legend()
plt.xlabel('DN / RH')
plt.ylabel('Height')
# Show the plot
plt.show()

# %%
# canopy height, canopy cover, Relative Height 
#(RH) metrics
# Canopy height and RH metrics
# python Possion distribution

# %%
# Set the parameters for the Poisson distribution
lambda_param = 3  # Mean parameter (adjust as needed)
# Generate a range of values for the x-axis (number of events)
x = np.arange(0, 11)  # Adjust the range as needed
# Calculate the CDF for each value of x
cdf = poisson.cdf(x, lambda_param)
# Plot the CDF
plt.plot(x, cdf, marker='o', linestyle='-')
plt.title(f'Poisson Distribution CDF (λ={lambda_param})')
plt.xlabel('Number of Events')
plt.ylabel('CDF')
plt.grid(True)
plt.show()

# %%
# normalize the wavefrom, so the sum  = 1

# %% [markdown]
# The second group of parameters are derived from photon events detected via the transmitter echo
# path (TEP). These photons are picked off from the transmitted laser pulse, and routed into the
# ATLAS receiver, for #two of the ATLAS strong beams. These data provide a means to monitor
# the internal timing bias of ATLAS, as well as the instrument impulse response for beams with
# the TEP data. The parameters are generated as often as sufficient TEP data exists in the ANC41
# data product (typically occurs about every five granules or twice an orbit); otherwise data from a
# reference TEP is included on the ATL03 granule. In addition to single-valued parameters, a
# histogram of the TEP photons are provided and the TEP photon event arrival times are also
# provided in tep_hist_time, so that a user can conduct their own analysis of the TEP arrival times.
# These parameters are described in section 7.2

# %%
###### merge h5 test ??? a little complex 
# List of input HDF5 file paths (replace with your file paths)
data_sim = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/wave/sim*.parquet'
files = glob.glob(data_sim)
df = []
for f in files:
    df1 = pd.read_parquet(files[1])
    df1.set_index('fid', inplace=True)
    df.append(df1)
result = pd.concat(df)

# %%
merged_df = result.merge(gdf_is2, left_index=True, right_index=True)

# %%
# plt plot 
# Create a plot
y = merged_df['land_segments/canopy/h_canopy_20m']
x = merged_df['h_canopy_98']
plt.scatter(x, y)

# Add labels and a title
plt.xlabel('is2')
plt.ylabel('sim')
plt.title('Plot of X and Y')
plt.xlim(0,50)
plt.ylim(0,50)
# Display the plot
plt.show()

# %%
for index, row in gdf_als.iterrows(): 
            print('# index: {}\n'.format(index))
            print('# now processing als project: {}\n'.format(row['region'] + '_' + row['name']))
# Out:
# # index: 0
#
# # now processing als project: usa_usda_or
#
# # index: 1
#
# # now processing als project: southamerica_embrapa_brazil_keller_2011_cot
#
# # index: 2
#
# # now processing als project: usa_cflra_waldepeteking
#
# # index: 3
#
# # now processing als project: usa_fernan_tepeepottercreek
#
# # index: 4
#
# # now processing als project: centralamerica_costarica_laselva2019
#
# # index: 5
#
# # now processing als project: seasia_jpl_borneo_119
#
# # index: 6
#
# # now processing als project: usa_neon_sawb
#
# # index: 7
#
# # now processing als project: africa_jpl_rabi
#
# # index: 8
#
# # now processing als project: europe_spain_exts2
#
# # index: 9
#
# # now processing als project: centralamerica_nasa_laselva
#
# # index: 10
#
# # now processing als project: usa_neon_yell2019
#
# # index: 11
#
# # now processing als project: usa_neon_dsny2018
#
# # index: 12
#
# # now processing als project: usa_canada_2010_32613
#
# # index: 13
#
# # now processing als project: africa_gsfc_mozambique
#
# # index: 14
#
# # now processing als project: southamerica_embrapa_brazil_2020_tap_a04
#
# # index: 15
#
# # now processing als project: usa_cflra_powell
#
# # index: 16
#
# # now processing als project: usa_neon_cper2021
#
# # index: 17
#
# # now processing als project: usa_neon_clbj2018
#
# # index: 18
#
# # now processing als project: africa_csir_agincourt
#
# # index: 19
#
# # now processing als project: centralamerica_gliht_mexico_nfi_32614
#
# # index: 20
#
# # now processing als project: usa_umn_mn_falkowski
#
# # index: 21
#
# # now processing als project: australia_newzealand_forestservice
#
# # index: 22
#
# # now processing als project: usa_cflra_clearcreek
#
# # index: 23
#
# # now processing als project: seasia_jpl_borneo_040
#
# # index: 24
#
# # now processing als project: europe_sweden_skog2018
#
# # index: 25
#
# # now processing als project: southamerica_jpl_wb_colombia
#
# # index: 26
#
# # now processing als project: usa_neon_stei2020
#
# # index: 27
#
# # now processing als project: usa_neon_moab2021
#
# # index: 28
#
# # now processing als project: africa_drc_ghent_field_32735
#
# # index: 29
#
# # now processing als project: usa_neon_jerc
#
# # index: 30
#
# # now processing als project: usa_slatecreek_2010
#
# # index: 31
#
# # now processing als project: africa_csir_ireagh
#
# # index: 32
#
# # now processing als project: usa_neon_blan2016
#
# # index: 33
#
# # now processing als project: usa_neon_heal2018
#
# # index: 34
#
# # now processing als project: centralamerica_gliht_mexico_nfi_32615
#
# # index: 35
#
# # now processing als project: usa_neon_tall2016
#
# # index: 36
#
# # now processing als project: southamerica_embrapa_brazil_2020_tap_a01
#
# # index: 37
#
# # now processing als project: usa_neon_wref2021
#
# # index: 38
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_fnb
#
# # index: 39
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_bon
#
# # index: 40
#
# # now processing als project: asia_khaoyai_thailand
#
# # index: 41
#
# # now processing als project: usa_cflra_lolocreekeldoradocreek
#
# # index: 42
#
# # now processing als project: southamerica_embrapa_brazil_2020_st2_a01
#
# # index: 43
#
# # now processing als project: southamerica_embrapa_brazil_2020_fn1_a01
#
# # index: 44
#
# # now processing als project: seasia_boyd_danum
#
# # index: 45
#
# # now processing als project: usa_neon_unde2016
#
# # index: 46
#
# # now processing als project: usa_canada_2010_32608
#
# # index: 47
#
# # now processing als project: europe_kellner_pfynwald
#
# # index: 48
#
# # now processing als project: seasia_jpl_borneo_008
#
# # index: 49
#
# # now processing als project: europe_dalponte_trentino
#
# # index: 50
#
# # now processing als project: usa_neon_sjer2019
#
# # index: 51
#
# # now processing als project: usa_falkowski_damon_2007
#
# # index: 52
#
# # now processing als project: usa_gliht_32606ak2018
#
# # index: 53
#
# # now processing als project: seasia_boyd_selangor
#
# # index: 54
#
# # now processing als project: usa_neon_soap
#
# # index: 55
#
# # now processing als project: centralamerica_gliht_mexico_nfi_32613
#
# # index: 56
#
# # now processing als project: asia_zhangye_china
#
# # index: 57
#
# # now processing als project: europe_ucl_wytham
#
# # index: 58
#
# # now processing als project: usa_neon_bldr_preflood
#
# # index: 59
#
# # now processing als project: usa_neon_konz2018
#
# # index: 60
#
# # now processing als project: usa_neon_serc2021
#
# # index: 61
#
# # now processing als project: usa_neon_dsny2021
#
# # index: 62
#
# # now processing als project: usa_neon_blan2017
#
# # index: 63
#
# # now processing als project: usa_neon_nogp2016
#
# # index: 64
#
# # now processing als project: usa_neon_grsm2015
#
# # index: 65
#
# # now processing als project: usa_neon_steicheq2017
#
# # index: 66
#
# # now processing als project: usa_neon_konz2017
#
# # index: 67
#
# # now processing als project: southamerica_embrapa_brazil_keller_2012_tan
#
# # index: 68
#
# # now processing als project: usa_neon_deju2017
#
# # index: 69
#
# # now processing als project: usa_neon_soap2021
#
# # index: 70
#
# # now processing als project: southamerica_embrapa_brazil_2020_st1_a01
#
# # index: 71
#
# # now processing als project: usa_neon_tall2018
#
# # index: 72
#
# # now processing als project: usa_gliht_32605ak2018
#
# # index: 73
#
# # now processing als project: europe_spain_exts4
#
# # index: 74
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_cag
#
# # index: 75
#
# # now processing als project: usa_neon_serc2019
#
# # index: 76
#
# # now processing als project: usa_neon_grsm2017
#
# # index: 77
#
# # now processing als project: usa_neon_jorn2018
#
# # index: 78
#
# # now processing als project: usa_usda_me
#
# # index: 79
#
# # now processing als project: australia_jrsrp_ilcp2015
#
# # index: 80
#
# # now processing als project: usa_neon_scbi2021
#
# # index: 81
#
# # now processing als project: australia_chowilla
#
# # index: 82
#
# # now processing als project: usa_canada_2010_32610
#
# # index: 83
#
# # now processing als project: asia_nagano_japan
#
# # index: 84
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_par
#
# # index: 85
#
# # now processing als project: usa_neon_bart2017
#
# # index: 86
#
# # now processing als project: southamerica_embrapa_brazil_2020_tap_a05
#
# # index: 87
#
# # now processing als project: australia_ara_smapex
#
# # index: 88
#
# # now processing als project: usa_gliht_32605ak2014
#
# # index: 89
#
# # now processing als project: usa_neon_konz2016
#
# # index: 90
#
# # now processing als project: southamerica_embrapa_brazil_2020_tan_a01
#
# # index: 91
#
# # now processing als project: australia_tern_alice_mulga
#
# # index: 92
#
# # now processing als project: usa_neon_deju2018
#
# # index: 93
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_fn1
#
# # index: 94
#
# # now processing als project: africa_jpl_mondah
#
# # index: 95
#
# # now processing als project: usa_neon_unde2019
#
# # index: 96
#
# # now processing als project: southamerica_embrapa_brazil_keller_2012_sfx
#
# # index: 97
#
# # now processing als project: usa_fitsum_southforksalmon
#
# # index: 98
#
# # now processing als project: africa_csir_venetia
#
# # index: 99
#
# # now processing als project: africa_drc_ghent_field_32734
#
# # index: 100
#
# # now processing als project: southamerica_embrapa_brazil_keller_2012_duc
#
# # index: 101
#
# # now processing als project: usa_neon_rmnp2017
#
# # index: 102
#
# # now processing als project: usa_neon_abby2019
#
# # index: 103
#
# # now processing als project: usa_neon_bart2016
#
# # index: 104
#
# # now processing als project: usa_stri_serc_Jun2012
#
# # index: 105
#
# # now processing als project: usa_neon_onaq2019
#
# # index: 106
#
# # now processing als project: usa_neon_bona2019
#
# # index: 107
#
# # now processing als project: africa_drc_ghent_field_32733
#
# # index: 108
#
# # now processing als project: usa_stjoe
#
# # index: 109
#
# # now processing als project: seasia_jpl_borneo_005
#
# # index: 110
#
# # now processing als project: africa_csir_justicia
#
# # index: 111
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_tan
#
# # index: 112
#
# # now processing als project: africa_tanzania_wwf_germany
#
# # index: 113
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_fn2
#
# # index: 114
#
# # now processing als project: usa_neon_heal2021
#
# # index: 115
#
# # now processing als project: usa_neon_dsny
#
# # index: 116
#
# # now processing als project: australia_litchfield
#
# # index: 117
#
# # now processing als project: europe_spain_extremadura
#
# # index: 118
#
# # now processing als project: australia_watts_creek
#
# # index: 119
#
# # now processing als project: usa_neon_serc
#
# # index: 120
#
# # now processing als project: seasia_malaysia_davidcoomes
#
# # index: 121
#
# # now processing als project: europe_veg3D_laegeren
#
# # index: 122
#
# # now processing als project: usa_neon_bona2018
#
# # index: 123
#
# # now processing als project: usa_neon_harv2019
#
# # index: 124
#
# # now processing als project: usa_neon_clbj2017
#
# # index: 125
#
# # now processing als project: usa_neon_deju2021
#
# # index: 126
#
# # now processing als project: usa_aso_sierra_nevada_snowoff
#
# # index: 127
#
# # now processing als project: europe_icos_bialowieza
#
# # index: 128
#
# # now processing als project: usa_neon_srer2019
#
# # index: 129
#
# # now processing als project: usa_fergusonfire_20180916
#
# # index: 130
#
# # now processing als project: usa_neon_wood2021
#
# # index: 131
#
# # now processing als project: usa_neon_cper2017
#
# # index: 132
#
# # now processing als project: usa_neon_bart2019
#
# # index: 133
#
# # now processing als project: africa_jpl_lope
#
# # index: 134
#
# # now processing als project: centralamerica_gliht_mexico_nfi_32612
#
# # index: 135
#
# # now processing als project: usa_neon_leno2021
#
# # index: 136
#
# # now processing als project: usa_nezperce
#
# # index: 137
#
# # now processing als project: usa_neon_scbi2016
#
# # index: 138
#
# # now processing als project: usa_neon_tall2019
#
# # index: 139
#
# # now processing als project: usa_gliht_32607ak2014
#
# # index: 140
#
# # now processing als project: usa_neon_dsny2016
#
# # index: 141
#
# # now processing als project: europe_spain_leonposada
#
# # index: 142
#
# # now processing als project: usa_neon_dsny2017
#
# # index: 143
#
# # now processing als project: usa_neon_bona2017
#
# # index: 144
#
# # now processing als project: usa_neon_dela2017
#
# # index: 145
#
# # now processing als project: southamerica_inpe_brazil_gorgens
#
# # index: 146
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_fst
#
# # index: 147
#
# # now processing als project: usa_neon_nogp2021
#
# # index: 148
#
# # now processing als project: southamerica_embrapa_brazil_2020_cau_a01
#
# # index: 149
#
# # now processing als project: southamerica_embrapa_brazil_2020_fn2_a01
#
# # index: 150
#
# # now processing als project: usa_neon_leno2019
#
# # index: 151
#
# # now processing als project: usa_usda_co
#
# # index: 152
#
# # now processing als project: usa_neon_clbj2019
#
# # index: 153
#
# # now processing als project: usa_neon_osbs
#
# # index: 154
#
# # now processing als project: usa_moscowmtn_2007
#
# # index: 155
#
# # now processing als project: southamerica_embrapa_brazil_2020_and_a01
#
# # index: 156
#
# # now processing als project: usa_neon_guan2018
#
# # index: 157
#
# # now processing als project: usa_neon_niwo2019
#
# # index: 158
#
# # now processing als project: europe_hill_newforest
#
# # index: 159
#
# # now processing als project: usa_neon_cper
#
# # index: 160
#
# # now processing als project: usa_neon_grsm
#
# # index: 161
#
# # now processing als project: seasia_jpl_borneo_013
#
# # index: 162
#
# # now processing als project: usa_neon_grsm2016
#
# # index: 163
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_san
#
# # index: 164
#
# # now processing als project: australia_g_aguilarNP
#
# # index: 165
#
# # now processing als project: southamerica_embrapa_brazil_keller_2012_cau
#
# # index: 166
#
# # now processing als project: usa_neon_jorn2021
#
# # index: 167
#
# # now processing als project: usa_neon_tall2017
#
# # index: 168
#
# # now processing als project: seasia_jpl_borneo_139
#
# # index: 169
#
# # now processing als project: usa_neon_abby2018
#
# # index: 170
#
# # now processing als project: usa_walkerfire_20191007
#
# # index: 171
#
# # now processing als project: usa_neon_bart
#
# # index: 172
#
# # now processing als project: southamerica_chave_nourages
#
# # index: 173
#
# # now processing als project: usa_neon_harv2016
#
# # index: 174
#
# # now processing als project: usa_nasa_sonoma
#
# # index: 175
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_rib
#
# # index: 176
#
# # now processing als project: usa_neon_leno2016
#
# # index: 177
#
# # now processing als project: usa_neon_wood2016
#
# # index: 178
#
# # now processing als project: usa_neon_konz2019
#
# # index: 179
#
# # now processing als project: europe_spain_leon2
#
# # index: 180
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_go1
#
# # index: 181
#
# # now processing als project: usa_cflra_dutchoven
#
# # index: 182
#
# # now processing als project: africa_csir_welverdient
#
# # index: 183
#
# # now processing als project: usa_neon_blan2021
#
# # index: 184
#
# # now processing als project: southamerica_embrapa_brazil_2020_rib_a01
#
# # index: 185
#
# # now processing als project: usa_tepeecreek_2014
#
# # index: 186
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_and
#
# # index: 187
#
# # now processing als project: europe_skidmore_bayerischer
#
# # index: 188
#
# # now processing als project: australia_zigzag_creek
#
# # index: 189
#
# # now processing als project: centralamerica_nasa_laselva_2009
#
# # index: 190
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_st1
#
# # index: 191
#
# # now processing als project: usa_neon_leno2018
#
# # index: 192
#
# # now processing als project: seasia_cambridge_sepilok
#
# # index: 193
#
# # now processing als project: europe_froscham
#
# # index: 194
#
# # now processing als project: asia_cuilai_china
#
# # index: 195
#
# # now processing als project: usa_neon_jorn2019
#
# # index: 196
#
# # now processing als project: southamerica_embrapa_brazil_2020_jar_a01b
#
# # index: 197
#
# # now processing als project: usa_gliht_32606ak2014
#
# # index: 198
#
# # now processing als project: southamerica_embrapa_brazil_2020_jar_a01d
#
# # index: 199
#
# # now processing als project: usa_neon_osbs2016
#
# # index: 200
#
# # now processing als project: europe_spain_valsaindemiguel
#
# # index: 201
#
# # now processing als project: usa_neon_srer2021
#
# # index: 202
#
# # now processing als project: europe_spain_leon3
#
# # index: 203
#
# # now processing als project: usa_fernan_fernan
#
# # index: 204
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_tac
#
# # index: 205
#
# # now processing als project: centralamerica_david_test
#
# # index: 206
#
# # now processing als project: usa_nasa_hubbard
#
# # index: 207
#
# # now processing als project: usa_canada_2010_32614
#
# # index: 208
#
# # now processing als project: seasia_jpl_borneo_144
#
# # index: 209
#
# # now processing als project: usa_canada_2010_32612
#
# # index: 210
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_fst
#
# # index: 211
#
# # now processing als project: usa_neon_tool2019
#
# # index: 212
#
# # now processing als project: usa_neon_stei2017
#
# # index: 213
#
# # now processing als project: usa_neon_blan2019
#
# # index: 214
#
# # now processing als project: usa_nasa_howland_2009
#
# # index: 215
#
# # now processing als project: australia_credo
#
# # index: 216
#
# # now processing als project: usa_umn_colville_2014
#
# # index: 217
#
# # now processing als project: usa_neon_rmnp2020
#
# # index: 218
#
# # now processing als project: europe_italy_sella
#
# # index: 219
#
# # now processing als project: usa_neon_leno
#
# # index: 220
#
# # now processing als project: usa_sagehen_20190730
#
# # index: 221
#
# # now processing als project: centralamerica_whrc_mexico_walker
#
# # index: 222
#
# # now processing als project: usa_neon_jerc2021
#
# # index: 223
#
# # now processing als project: usa_neon_teak2017
#
# # index: 224
#
# # now processing als project: southamerica_chave_paracou
#
# # index: 225
#
# # now processing als project: usa_nasa_howland
#
# # index: 226
#
# # now processing als project: usa_neon_jerc2017
#
# # index: 227
#
# # now processing als project: usa_dcef_nfp_2011
#
# # index: 228
#
# # now processing als project: europe_spain_leon1
#
# # index: 229
#
# # now processing als project: usa_neon_heal2017
#
# # index: 230
#
# # now processing als project: usa_boschetti_idaho_selway
#
# # index: 231
#
# # now processing als project: africa_amani
#
# # index: 232
#
# # now processing als project: usa_slatecreek_2008
#
# # index: 233
#
# # now processing als project: usa_neon_osbs2021
#
# # index: 234
#
# # now processing als project: europe_kljun_tharandt
#
# # index: 235
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_ba3
#
# # index: 236
#
# # now processing als project: southamerica_embrapa_brazil_2020_jar_a01c
#
# # index: 237
#
# # now processing als project: southamerica_embrapa_brazil_keller_2008_tap
#
# # index: 238
#
# # now processing als project: europe_zofin_180416
#
# # index: 239
#
# # now processing als project: usa_neon_yell2018
#
# # index: 240
#
# # now processing als project: usa_pref_pref
#
# # index: 241
#
# # now processing als project: southamerica_embrapa_brazil_keller_2011_jam
#
# # index: 242
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_tal
#
# # index: 243
#
# # now processing als project: usa_cflra_crookedriver
#
# # index: 244
#
# # now processing als project: usa_aso_sierra_nevada
#
# # index: 245
#
# # now processing als project: usa_umn_colville_2012
#
# # index: 246
#
# # now processing als project: usa_neon_tall2021
#
# # index: 247
#
# # now processing als project: usa_neon_ukfs2016
#
# # index: 248
#
# # now processing als project: usa_neon_puum2020
#
# # index: 249
#
# # now processing als project: usa_neon_steicheq2016
#
# # index: 250
#
# # now processing als project: europe_rami_jarvselja
#
# # index: 251
#
# # now processing als project: centralamerica_nasa_laselva_2006
#
# # index: 252
#
# # now processing als project: usa_canada_2010_32609
#
# # index: 253
#
# # now processing als project: seasia_jpl_borneo_001
#
# # index: 254
#
# # now processing als project: southamerica_embrapa_brazil_keller_2012_tap
#
# # index: 255
#
# # now processing als project: usa_neon_moab2017
#
# # index: 256
#
# # now processing als project: centralamerica_gliht_mexico_nfi_32616
#
# # index: 257
#
# # now processing als project: usa_canada_petawawa2012
#
# # index: 258
#
# # now processing als project: centralamerica_nasa_laselva_1997
#
# # index: 259
#
# # now processing als project: southamerica_embrapa_brazil_2020_jar_a01a
#
# # index: 260
#
# # now processing als project: usa_neon_ukfs2018
#
# # index: 261
#
# # now processing als project: africa_drc_ghent_field_32634
#
# # index: 262
#
# # now processing als project: usa_pref_fia
#
# # index: 263
#
# # now processing als project: usa_neon_clbj2021
#
# # index: 264
#
# # now processing als project: europe_spain_monfrague
#
# # index: 265
#
# # now processing als project: usa_neon_jerc2016
#
# # index: 266
#
# # now processing als project: usa_neon_ukfs2017
#
# # index: 267
#
# # now processing als project: usa_moscowmtn_2009
#
# # index: 268
#
# # now processing als project: usa_neon_harv2017
#
# # index: 269
#
# # now processing als project: usa_dcef_nfp_2010
#
# # index: 270
#
# # now processing als project: usa_umn_colvilleeast_2015
#
# # index: 271
#
# # now processing als project: usa_neon_osbs2019
#
# # index: 272
#
# # now processing als project: usa_neon_dela2019
#
# # index: 273
#
# # now processing als project: usa_stri_serc_Oct2011
#
# # index: 274
#
# # now processing als project: usa_neon_sjer
#
# # index: 275
#
# # now processing als project: usa_neon_mlbs2021
#
# # index: 276
#
# # now processing als project: usa_fergusonfire_20180722
#
# # index: 277
#
# # now processing als project: australia_tern_robson
#
# # index: 278
#
# # now processing als project: usa_neon_dela2015
#
# # index: 279
#
# # now processing als project: australia_tern_robson_whole
#
# # index: 280
#
# # now processing als project: australia_oeh_ausplotsforests
#
# # index: 281
#
# # now processing als project: usa_neon_ukfs2019
#
# # index: 282
#
# # now processing als project: europe_tellus_sw_uk
#
# # index: 283
#
# # now processing als project: usa_neon_ukfs2020
#
# # index: 284
#
# # now processing als project: europe_spain_exts3
#
# # index: 285
#
# # now processing als project: usa_neon_osbs2017
#
# # index: 286
#
# # now processing als project: usa_usda_panj
#
# # index: 287
#
# # now processing als project: usa_neon_konz2020
#
# # index: 288
#
# # now processing als project: usa_neon_niwo2017
#
# # index: 289
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_tap
#
# # index: 290
#
# # now processing als project: southamerica_embrapa_brazil_keller_2008_duc
#
# # index: 291
#
# # now processing als project: usa_neon_harv
#
# # index: 292
#
# # now processing als project: southamerica_embrapa_brazil_2020_duc_a01
#
# # index: 293
#
# # now processing als project: usa_neon_puum2019
#
# # index: 294
#
# # now processing als project: southamerica_embrapa_brazil_keller_2008_cui
#
# # index: 295
#
# # now processing als project: usa_upperlolo
#
# # index: 296
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_jam
#
# # index: 297
#
# # now processing als project: usa_neon_dcfs2016
#
# # index: 298
#
# # now processing als project: usa_neon_jerc2018
#
# # index: 299
#
# # now processing als project: usa_neon_steicheq2019
#
# # index: 300
#
# # now processing als project: southamerica_embrapa_brazil_2020_tal_a01
#
# # index: 301
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_st2
#
# # index: 302
#
# # now processing als project: australia_gold01
#
# # index: 303
#
# # now processing als project: usa_umn_colvillewest_2015
#
# # index: 304
#
# # now processing als project: usa_neon_scbi2019
#
# # index: 305
#
# # now processing als project: usa_usda_sc
#
# # index: 306
#
# # now processing als project: centralamerica_stri_bci
#
# # index: 307
#
# # now processing als project: usa_neon_abby
#
# # index: 308
#
# # now processing als project: usa_canada_2010_32619
#
# # index: 309
#
# # now processing als project: europe_demiguel_soriaii
#
# # index: 310
#
# # now processing als project: usa_neon_laja2018
#
# # index: 311
#
# # now processing als project: usa_nasa_sierra
#
# # index: 312
#
# # now processing als project: usa_neon_soap2018
#
# # index: 313
#
# # now processing als project: seasia_disney_danum
#
# # index: 314
#
# # now processing als project: southamerica_embrapa_brazil_2020_hum_a01
#
# # index: 315
#
# # now processing als project: usa_neon_ster
#
# # index: 316
#
# # now processing als project: usa_stanley_stanley
#
# # index: 317
#
# # now processing als project: seasia_jpl_borneo_004
#
# # index: 318
#
# # now processing als project: europe_kljun_loobos
#
# # index: 319
#
# # now processing als project: usa_neon_wref
#
# # index: 320
#
# # now processing als project: usa_nasa_sonoma_whole
#
# # index: 321
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_jam
#
# # index: 322
#
# # now processing als project: usa_neon_unde2020
#
# # index: 323
#
# # now processing als project: europe_silvanet_valsain
#
# # index: 324
#
# # now processing als project: usa_moscowmtn_2003
#
# # index: 325
#
# # now processing als project: usa_cflra_selwayriverelkcreek
#
# # index: 326
#
# # now processing als project: usa_neon_dela2021
#
# # index: 327
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_st3
#
# # index: 328
#
# # now processing als project: usa_neon_teak2021
#
# # index: 329
#
# # now processing als project: seasia_jpl_borneo_219
#
# # index: 330
#
# # now processing als project: usa_neon_tall2015
#
# # index: 331
#
# # now processing als project: southamerica_embrapa_brazil_2020_bon_a01
#
# # index: 332
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_bar
#
# # index: 333
#
# # now processing als project: usa_neon_unde2017
#
# # index: 334
#
# # now processing als project: usa_nasa_ma
#
# # index: 335
#
# # now processing als project: usa_neon_niwo2020
#
# # index: 336
#
# # now processing als project: usa_neon_bona2021
#
# # index: 337
#
# # now processing als project: usa_neon_moab2018
#
# # index: 338
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_fna
#
# # index: 339
#
# # now processing als project: usa_neon_stei2019
#
# # index: 340
#
# # now processing als project: usa_neon_prov
#
# # index: 341
#
# # now processing als project: usa_neon_mlbs2015
#
# # index: 342
#
# # now processing als project: australia_karawatha
#
# # index: 343
#
# # now processing als project: usa_neon_grsm2018
#
# # index: 344
#
# # now processing als project: usa_neon_mlbs2018
#
# # index: 345
#
# # now processing als project: usa_neon_dela2018
#
# # index: 346
#
# # now processing als project: usa_neon_wref2019
#
# # index: 347
#
# # now processing als project: southamerica_embrapa_brazil_2020_par_a01
#
# # index: 348
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_fn3
#
# # index: 349
#
# # now processing als project: usa_neon_ornl
#
# # index: 350
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_cau
#
# # index: 351
#
# # now processing als project: australia_rushworth_forests
#
# # index: 352
#
# # now processing als project: usa_dcef_nfp_2009
#
# # index: 353
#
# # now processing als project: usa_neon_scbi2017
#
# # index: 354
#
# # now processing als project: africa_jpl_mabounie
#
# # index: 355
#
# # now processing als project: europe_huuth_traunstein
#
# # index: 356
#
# # now processing als project: usa_ltbmu_20180710
#
# # index: 357
#
# # now processing als project: usa_neon_leno2017
#
# # index: 358
#
# # now processing als project: usa_neon_soap2019
#
# # index: 359
#
# # now processing als project: usa_neon_abby2021
#
# # index: 360
#
# # now processing als project: usa_neon_harv2018
#
# # index: 361
#
# # now processing als project: usa_neon_deju2019
#
# # index: 362
#
# # now processing als project: usa_neon_rmnp2018
#
# # index: 363
#
# # now processing als project: usa_canada_2010_32618
#
# # index: 364
#
# # now processing als project: usa_neon_dela2016
#
# # index: 365
#
# # now processing als project: usa_neon_heal2019
#
# # index: 366
#
# # now processing als project: usa_neon_jorn2017
#
# # index: 367
#
# # now processing als project: usa_neon_bldr_postflood
#
# # index: 368
#
# # now processing als project: southamerica_embrapa_brazil_keller_2013_hum
#
# # index: 369
#
# # now processing als project: usa_neon_onaq2017
#
# # index: 370
#
# # now processing als project: africa_csir_dnyala
#
# # index: 371
#
# # now processing als project: usa_neon_ster2021
#
# # index: 372
#
# # now processing als project: europe_zofin_180607
#
# # index: 373
#
# # now processing als project: southamerica_embrapa_brazil_keller_2012_sdm
#
# # index: 374
#
# # now processing als project: southamerica_embrapa_brazil_2020_tap_a06
#
# # index: 375
#
# # now processing als project: usa_neon_teak
#
# # index: 376
#
# # now processing als project: usa_neon_yell2020
#
# # index: 377
#
# # now processing als project: usa_neon_sjer2017
#
# # index: 378
#
# # now processing als project: usa_canada_2010_26917
#
# # index: 379
#
# # now processing als project: seasia_jpl_borneo_138
#
# # index: 380
#
# # now processing als project: africa_drc_ghent_field_32635
#
# # index: 381
#
# # now processing als project: usa_neon_bart2018
#
# # index: 382
#
# # now processing als project: southamerica_embrapa_brazil_keller_2008_pre
#
# # index: 383
#
# # now processing als project: usa_neon_barr2019
#
# # index: 384
#
# # now processing als project: australia_warra
#
# # index: 385
#
# # now processing als project: usa_neon_grsm2021
#
# # index: 386
#
# # now processing als project: usa_stri_serc_Mar2012
#
# # index: 387
#
# # now processing als project: usa_neon_osbs2018
#
# # index: 388
#
# # now processing als project: southamerica_hill_peru
#
# # index: 389
#
# # now processing als project: usa_cascadeeastzone
#
# # index: 390
#
# # now processing als project: usa_usda_mn
#
# # index: 391
#
# # now processing als project: usa_neon_stei2016
#
# # index: 392
#
# # now processing als project: seasia_whrc_indonesia_walker
#
# # index: 393
#
# # now processing als project: europe_spain_exts1
#
# # index: 394
#
# # now processing als project: usa_neon_onaq2021
#
# # index: 395
#
# # now processing als project: southamerica_embrapa_brazil_keller_2014_can
#
# # index: 396
#
# # now processing als project: southamerica_embrapa_brazil_keller_2011_ant
#
# # index: 397
#
# # now processing als project: usa_neon_serc2016
#
# # index: 398
#
# # now processing als project: usa_neon_soap2017
#
# # index: 399
#
# # now processing als project: usa_nasa_me
#
# # index: 400
#
# # now processing als project: usa_cflra_twincreek
#
# # index: 401
#
# # now processing als project: usa_plumasnf_20180717
#
# # index: 402
#
# # now processing als project: australia_whroo
#
# # index: 403
#
# # now processing als project: usa_neon_srer2017
#
# # index: 404
#
# # now processing als project: usa_neon_jerc2019
#
# # index: 405
#
# # now processing als project: usa_neon_steicheq2020
#
# # index: 406
#
# # now processing als project: usa_boschetti_idaho_clearcreek

# %%
# index: 4
# # now processing als project: centralamerica_costarica_laselva2019
# La_Selva_05102019_001_827800_1155000_0000000.las
# get wave
out_las
out_coor
out_wave
os.system(f'gediRat -fSigma 2.75 -readPulse 20190821.gt1l.pulse -inList {out_las} -listCoord {out_coor}  -output {out_wave} -hdf  -ground > running.log')

# %%
#### 11/08/2023 test wave 
filename = '/gpfs/data1/vclgp/xiongl/ProjectIS2CalVal/result/usa/usda_or/wave_or_22_222.h5'
start = 0
end = 28

# Canopy height, ch
# For a 100 m segment, the cumulative height distribution of canopy photons is 
# generated and the height at the 98th percentile.
with h5py.File(filename, "r") as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    #print("Keys: %s" % f.keys())
    N_foorprints = f['RXWAVECOUNT'].shape[0]
    pho_w_ground = pd.DataFrame()
    
    for i in range(start, end+1): # inclusive
                
                RXWAVECOUNT = f['RXWAVECOUNT'][i]
                GRWAVECOUNT = f['GRWAVECOUNT'][i]
                zStart = f["Z0"][i]
                zEnd = f["ZN"][i]
                zG = f["ZG"][i]
                wfCount = f["NBINS"][0]
                if (wfCount < 1): continue
                wfStart = 1
                # Calculate zStretch
                zStretch = zEnd + (np.arange(wfCount, 0, -1) * ((zStart - zEnd) / wfCount))
                # plt.plot(RXWAVECOUNT, zStretch,color='red' )
                # plt.plot(RXWAVECOUNT - GRWAVECOUNT, zStretch,color='black', linestyle='--' )
                # plt.show()
                # sampling 
                n = np.random.poisson(3,1)[0] # posson sample, how many photons?
                
                # canopy + ground photons
                rows = np.arange(RXWAVECOUNT.shape[0])
                total = sum(RXWAVECOUNT)
                
                # Normalize the data by dividing each value by the total
                p_data = [value / total for value in RXWAVECOUNT]
                photon_rows = np.random.choice(rows, size=n, p=p_data)
                df1 = zStretch[photon_rows] - zG
                df1 = pd.DataFrame(df1)
                # add a ground flag to df1 
                df1['ground_flag'] = GRWAVECOUNT[photon_rows] >0 
                
                if (len(pho_w_ground) == 0):
                    pho_w_ground = df1
                else:
                    #print(df1)
                    pho_w_ground = pd.concat([pho_w_ground, df1], ignore_index=True)
                
                
f.close()
percentiles = np.arange(1, 101, 1)
pho_no_ground = pho_w_ground[pho_w_ground['ground_flag'] == False]
if (len(pho_no_ground) == 0):
    ch_98=-999
else:
    height_percentiles = np.percentile(pho_no_ground, percentiles)
    ch_98 = height_percentiles[97] ### h_98

# rh 
percentiles = np.arange(0, 101, 1)
#0 --> min height
# 100 --> max height
height_percentiles = np.percentile(pho_w_ground, percentiles)
# data frame from 0 to 100
column_names = ["rh" + str(i) for i in range(101)]  # Creates a list from rh0 to rh100
sim = pd.DataFrame(columns=column_names)
# Add your array as a row to the DataFrame
sim.loc[0] = height_percentiles
sim['h_canopy_98'] = ch_98
#return sim

# %%
sim
# Out:
#         rh0       rh1       rh2       rh3       rh4       rh5       rh6  \
# 0 -0.802355 -0.758595 -0.463661 -0.414342 -0.266724 -0.196524 -0.117779
#
#         rh7  rh8  rh9  ...      rh92      rh93      rh94      rh95      rh96  \
# 0 -0.051996  0.0  0.0  ...  4.993225  5.312065  5.662848  5.860848  6.064851
#
#        rh97     rh98      rh99     rh100 h_canopy_98
# 0  7.058451  7.50553  9.158357  9.698081    9.160518
#
# [1 rows x 102 columns]
